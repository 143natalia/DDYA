# %% [markdown]
# ## 1) Descripción del problema
# Una empresa de distribución cuenta con varias bodegas interconectadas mediante rutas directas. Sin embargo, no dispone de una herramienta que le permita visualizar, recorrer y analizar la red de conexiones entre estas bodegas.
#
# El problema consiste en modelar esta red como un grafo no dirigido, donde:
# Cada bodega es un vértice
# Cada conexión es una arista bidireccional
#
# Se requiere implementar algoritmos que permitan recorrer la red desde una bodega principal, implementando estructuras de grafos, y los metodos de recorrido BFS y DFS.
# El usuari debe ser quien determina el nombre y número de bodegas y sus conecciones entre ellas. Tanto al iniciar el programa como posteriormente, el usuario debe ser capaz de agregar cuantos datos quiera, y tendra un menú con las opciones para el tipo de recorrido que desea verificar, y comparar las dos opciones disponibles.

# %% [markdown]
# ## 2) Requerimientos
# **funcionales**
# - RF-01: Crear el grafo: Permitir registrar bodegas (vértices) y conexiones (aristas)
# - RF-02: Imprimir la estructura del grafo con base a los datos dados y la lista de adyacencia
# - RF-03: Ejecutar recorrido BFS, usando una cola para administrar los nodos pendientes y marcar los nodos visitados para evitar repeticiones, explorar los vecinos en orden alfabético, e imprimir el recorrido final obtenido.
# - RF-04: Ejecutar recorrido DFS, usando recursión o una pila, marcando los nodos visitados, explorando los vecinos en orden alfabético, e imprimir el recorrido final obtenido.
# - RF-05: Comparar resultados y las diferencias entre recorridos BFS y DFS, incluye que el mismo programa recomiende la mejor opción.
# - RF-06: Permite añadir nuevas bodegas y sus conecciones, actualizar el grafo y sus nuevos recorridos
#
# **no funcionales**
# -  RNF-01: No utilizar librerias
# -  RNF-02: No utilizar Collections
# -  RNF-03: Escalabilidad, debe permitir agregar más nodos sin rediseñar el sistema
# -  RNF-04: Consistencia, los vecinos deben recorrerse en orden alfabético para resultados reproducibles
# -  RNF-04: Lenguaje de programación: Python

# %% [markdown]
# ## 3) Historias de usuario

# %% [markdown]
# ![Image](https://github.com/143natalia/DDYA/blob/back/imagenes%209/Captura%20de%20pantalla%202026-03-22%20103827.png?raw=true)

# %% [markdown]
# ## 4) Diagramas de flujo
# Diagrama de flujo que describe el proceso de creación y gestión de un grafo, donde el usuario ingresa bodegas y rutas y luego selecciona opciones como generar la lista de adyacencia, realizar recorridos BFS/DFS o comparar resultados. También permite modificar el grafo añadiendo nuevas bodegas y rutas antes de finalizar el programa.

# %% [markdown]
# <div>
# <img src="https://github.com/143natalia/DDYA/blob/back/imagenes%209/_Diagrama%20de%20flujo%209.png?raw=true" width="1000"/>
# </div>

# %% [markdown]
# ## 5) Diagramas de secuencia
# Diagrama de secuencia que muestra cómo un usuario interactúa con un sistema para ingresar datos de un grafo (bodegas y rutas), construir su lista de adyacencia y ejecutar recorridos BFS y DFS. Además, incluye la comparación de resultados, la recomendación de la mejor opción y la posibilidad de modificar el grafo con nuevos datos.

# %% [markdown]
# <div>
# <img src="https://github.com/143natalia/DDYA/blob/back/imagenes%209/Diagrama%20secuencia%209.png?raw=true" width="1000"/>
# </div>

# %% [markdown]
# ## 6) Diagramas de casos de uso
# Diagrama de casos de uso donde un coordinador administrativo interactúa con un sistema para crear, visualizar y modificar una red de rutas entre bodegas. También permite realizar recorridos BFS y DFS, así como compararlos para obtener mejores resultados.

# %% [markdown]
# <div>
# <img src="https://github.com/143natalia/DDYA/blob/back/imagenes%209/red%20de%20rutas%20de%20bodegas.png?raw=true" width="1000"/>
# </div>

# %% [markdown]
# ## 7) Análisis de complejidad
# Complejidad Temporal: O(V + E)
#
# V = número de vertices
# E = número de aristas

# %% [markdown]
# ## 8) Tests

# %%
#Prueba 1:
'''
A,B,C,D,E,F,G,H
9
A B
A C
A A
B D
B E
C F
E G
F H
G H
1
2
A
3
A
4
A
D
5
I
2
I E
I H
1
6
'''

# %%
#Prueba 2:
'''
A,B,C,D
2
A B
C D
1
2
A 
3
C
5
E 
1
E D
1
2
E
3
E
6
'''

# %% [markdown]
# ## 9) Código funcional

# %%
def inicializa_datos(bodegas, rutas):
    ing_bodegas = input("Ingrese el nombre de las bodegas, separadas por comas (1,2,a,r,66): ")
    lista_bodegas = [b.strip() for b in ing_bodegas.split(",")]
    for b in lista_bodegas:
        bodegas[b] = []
    
    num_rutas = int(input("Ingrese en número de rutas entre bodegas: "))
    i = 1
    print("Ingrese la conecciones entre dos bodegas, formato A B, 1 2, 67 69")
    while i <= num_rutas:
        ruta = ()
        rut = input(f"Ruta {i}: ")
        origen, destino = rut.split(" ")
        ruta = (origen, destino)
        rutas.append(ruta)
        i += 1

    for origen, destino in rutas:
        if origen != destino:  
            if destino not in bodegas[origen]:
                bodegas[origen].append(destino)
            if origen not in bodegas[destino]:
                bodegas[destino].append(origen)

    return bodegas, rutas

def modificar_grafo(bodegas, rutas):
    nuevos = input("Ingrese nueva(s) bodega(s) (separados por comas): ")
    nuevos_b = [b.strip() for b in nuevos.split(",")]
    for b in nuevos_b:
        if b not in bodegas:
            bodegas[b] = []
        else:
            print(f"El vértice {b} ya existe")

    
    nuevas_r = int(input("Ingrese en número de nuevas rutas entre bodegas: "))
    i = 1
    print("\nIngrese nuevas rutas (ej: A B): ")
    while i <= nuevas_r:
        r = ()
        rut = input(f"Ruta {i}: ")
        origen, destino = rut.split(" ")
        r = (origen, destino)
        rutas.append(r)
        i += 1
    for origen, destino in rutas:
        if origen != destino:  
            if destino not in bodegas[origen]:
                bodegas[origen].append(destino)
            if origen not in bodegas[destino]:
                bodegas[destino].append(origen)
    return bodegas, rutas

def agregar_arista(bodegas, u, v):
    if u == v:
        bodegas[u].append(v)
    if u not in bodegas[v]:
        bodegas[v].append(u)
    if v not in bodegas[u]:
        bodegas[u].append(v)

def lista_adjacencia(aristas, bodegas):
    for u, v in aristas:
        agregar_arista(bodegas, u, v)
    for v in bodegas:
        bodegas[v] = sorted(bodegas[v])

    print("Lista de adyacencia:")
    for v in bodegas:
        print(f"{v}: {bodegas[v]}")


def bfs(bodegas, inicio):
    visitados = []  
    cola = [] 
    cola.append(inicio)
    visitados.append(inicio) 

    while cola:
        nodo = cola.pop(0)
        print(nodo)

        for vecino in bodegas[nodo]:
            if vecino not in visitados:
                visitados.append(vecino)
                cola.append(vecino)
    return visitados

def recorrido_dfs(bodegas, nodo, visitados):
    print(nodo)
    for vecino in bodegas[nodo]:
        if vecino not in visitados:
            visitados.append(vecino)
            recorrido_dfs(bodegas, vecino, visitados)
    return visitados

def comparacion(bodegas, inicio, llegada):
    visitados = []
    visitados.append(inicio)
    recorrido_bfs = bfs(bodegas, inicio)
    dfs= recorrido_dfs(bodegas, inicio, visitados)
    print(f"recorricod con dfs: {dfs}")
    print(f"recorricod con bfs: {recorrido_bfs}")
    pos1 = 0
    pos2 = 0
    total = len(dfs)
    for i in range(total):
        if dfs[i] == llegada:
            pos1 = i
        if recorrido_bfs == llegada:
            pos2 = i
    if pos1 < pos2:
        print(f"La mejor opción para llegar a {llegada} desde {inicio} es seguir el recorrido DFS")
    else:
        print(f"La mejor opción para llegar a {llegada} desde {inicio} es seguir el recorrido BFS")

def menu(bodegas, rutas):
    print("\nMENÚ\n\n1) Imprimir lista de adjacencia\n2) Mostrar recorrido de todas las bodegas estilo BFS\n3) Mostrar recorrido de todas las bodegas estilo DFS\n4) Comparar los recorridos BFS y DFS y recomendar el mejor\n5) Agregar nuevas bodegas y rutas\n6) Terminar programa")
    opcion = int(input("Escoga la opción que desea ejecutar: "))


    if opcion == 1:
        lista_adjacencia(rutas, bodegas)
        menu(bodegas, rutas)
    if opcion == 2:
        inicio = input("¿Por cúal bodega empezar el recorrido?: ")
        recorrido_bfs = bfs(bodegas, inicio)
        print(f"recorrido con bfs: {recorrido_bfs}")
        menu(bodegas, rutas)
    if opcion == 3:
        inicio = input("¿Por cúal bodega empezar el recorrido?: ")
        visitados = []
        visitados.append(inicio)
        dfs= recorrido_dfs(bodegas, inicio, visitados)
        print(f"recorrido con dfs: {dfs}")
        menu(bodegas, rutas)
    if opcion == 4:
        inicio = input("¿Por cúal bodega empezar el recorrido?: ")
        llegada = input("¿A cúal bodega desea llegar?: ")
        comparacion(bodegas, inicio, llegada)
        menu(bodegas, rutas)
    if opcion == 5:
        bodegas, rutas = modificar_grafo(bodegas, rutas)
        menu(bodegas, rutas)
    if opcion == 6:
        print("Programa finalizado")
        exit()


def main():
    print("WAZE PARA TUS VIAJES ENTRE BODEGAS")
    print("Para iniciar el programa, se necesita la información de tus bodegas y las rutas entre ellas")

    bodegas = {}
    rutas = []
    bodegas, rutas = inicializa_datos(bodegas, rutas)
    menu(bodegas, rutas)

main()

# %% [markdown]
# ## 10) Tests aplicados (extras)
# Muestra evidencia de pruebas ejecutadas:
# Incluye al menos 2 pruebas adicionales

# %%
#Resultados Prueba 1

'''WAZE PARA TUS VIAJES ENTRE BODEGAS
Para iniciar el programa, se necesita la información de tus bodegas y las rutas entre ellas
Ingrese el nombre de las bodegas, separadas por comas (1,2,a,r,66): A,B,C,D,E,F,G,H
Ingrese en número de rutas entre bodegas: 9
Ingrese la conecciones entre dos bodegas, formato A B, 1 2, 67 69
Ruta 1: A B
Ruta 2: A C
Ruta 3: A A
Ruta 4: B D
Ruta 5: B E
Ruta 6: C F
Ruta 7: E G
Ruta 8: F H
Ruta 9: G H

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 1
Lista de adyacencia:
A: ['A', 'B', 'C']
B: ['A', 'D', 'E']
C: ['A', 'F']
D: ['B']
E: ['B', 'G']
F: ['C', 'H']
G: ['E', 'H']
H: ['F', 'G']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 2
¿Por cúal bodega empezar el recorrido?: A
A
B
C
D
E
F
G
H
recorrido con bfs: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 3
¿Por cúal bodega empezar el recorrido?: A
A
B
D
E
G
H
F
C
recorrido con dfs: ['A', 'B', 'D', 'E', 'G', 'H', 'F', 'C']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 4
¿Por cúal bodega empezar el recorrido?: A
¿A cúal bodega desea llegar?: D
A
B
C
D
E
F
G
H
A
B
D
E
G
H
F
C
recorricod con dfs: ['A', 'B', 'D', 'E', 'G', 'H', 'F', 'C']
recorricod con bfs: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
La mejor opción para llegar a D desde A es seguir el recorrido BFS

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 5
Ingrese nueva(s) bodega(s) (separados por comas): I
Ingrese en número de nuevas rutas entre bodegas: 2

Ingrese nuevas rutas (ej: A B):
Ruta 1: I E
Ruta 2: I H

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 6
Programa finalizado'''

# %%
#Prueba 2
'''Ingrese el nombre de las bodegas, separadas por comas (1,2,a,r,66): A,B,C,D
Ingrese en número de rutas entre bodegas: 2
Ingrese la conecciones entre dos bodegas, formato A B, 1 2, 67 69
Ruta 1: A B
Ruta 2: C D

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 1
Lista de adyacencia:
A: ['B']
B: ['A']
C: ['D']
D: ['C']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 2
¿Por cúal bodega empezar el recorrido?: A
A
B
recorrido con bfs: ['A', 'B']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 3
¿Por cúal bodega empezar el recorrido?: C
C
D
recorrido con dfs: ['C', 'D']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 5
Ingrese nueva(s) bodega(s) (separados por comas): E
Ingrese en número de nuevas rutas entre bodegas: 1

Ingrese nuevas rutas (ej: A B):
Ruta 1: E D

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 1
Lista de adyacencia:
A: ['B', 'B', 'B']
B: ['A', 'A', 'A']
C: ['D', 'D', 'D']
D: ['C', 'C', 'C', 'E', 'E']
E: ['D', 'D']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 2
¿Por cúal bodega empezar el recorrido?: E
E
D
C
recorrido con bfs: ['E', 'D', 'C']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 3
¿Por cúal bodega empezar el recorrido?: E
E
D
C
recorrido con dfs: ['E', 'D', 'C']

MENÚ

1) Imprimir lista de adjacencia
2) Mostrar recorrido de todas las bodegas estilo BFS
3) Mostrar recorrido de todas las bodegas estilo DFS
4) Comparar los recorridos BFS y DFS y recomendar el mejor
5) Agregar nuevas bodegas y rutas
6) Terminar programa
Escoga la opción que desea ejecutar: 6
Programa finalizado'''
